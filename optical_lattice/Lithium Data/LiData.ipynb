# %%
# %matplotlib inline 

import matplotlib as mpl
import numpy as np
import matplotlib.pyplot as plt
import h5py
from PIL import Image 
from pathlib import Path

# %%
filename = Path('../data/Scan-20200201-0006.hdf')
file = h5py.File(filename, 'r')
img = file['Shot-0001']['Cameras']['IStar']['Image-0000'] # where Shot-XXXX = 0000, ...., 0005
type(img)
# Out:
# h5py._hl.dataset.Dataset

# %%
img_array = img[()] #convert the data set into a numpy array
type(img_array)
# Out:
# numpy.ndarray

# %%
print(img_array.max(),img_array.min())
# Out:
# 5407 608

# %%
plt.figure(figsize=(7,7))
plt.imshow(img_array);
# plt.xlim(350, 750);
# plt.ylim(550, 950);
plt.axis(True);

# %% [markdown]
# ## PSF

# %%
import gzip
import pickle

with open('20191216-0030.pkl', 'rb') as f:
    u = pickle._Unpickler(f)
    u.encoding = 'latin1'
    p = u.load()

# %%
PSF = p['avgPSF']
p['PSFmag'] #be careful with this, PSF has different magnification
# Out:
# 4

# %%
plt.figure(figsize=(7,7))
plt.imshow(PSF);
plt.axis(True);

# %%
plt.plot(PSF[60, :]);
