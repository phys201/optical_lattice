# %%
from lattice_image import LatticeImage
# %matplotlib inline

# %% [markdown]
# Let's import a raw .jpeg image into our `LatticeImage` class:

# %%
# Some name.
name = "Testimage"

# Dimension of atom lattice (in one direction)
N = 5

# Pixels per lattice site (in one direction)
M = 61

# Path of .image file.
image_path = "static files/test_lattice_image.png"


# Instanciate LatticeImage class
lattice_image = LatticeImage(
    name=name,
    M=M,
    N=N,
    image_path=image_path
)

# %% [markdown]
# Let's first look at the unproccessed picture file:

# %%
lattice_image.show_raw_image()

# %% [markdown]
# The initialization function of the `LatticeImage` class has automaticall remformatted the image  and broke it down in lattice sites. Let's have a look:

# %%
lattice_image.plot_image()
